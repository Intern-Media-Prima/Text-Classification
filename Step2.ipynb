# %%
from urllib.request import urlopen
import pickle
import pandas as pd
import re
import nltk
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import chi2
import numpy as np

# %%
stemmer = StemmerFactory().create_stemmer()
stop_words = set(urlopen('https://gist.githubusercontent.com/xxMrPHDxx/d7244906ff8159f6e030790162542524/raw/5ce745520a75af453eda44286ea75bf310a4702f/stopword-malay.txt').read().decode('utf-8').split('\n'))

# %%
# Create initial dataset
from os import mkdir, listdir
from os.path import isdir, exists

File_Name, Content, Category, Complete_Filename, id, News_length = [[] for _ in range(6)]
category_map = {corpus.replace('-', ' '): i for i, corpus in enumerate(listdir('articles'))}
for corpus in listdir('articles'):
    folder = 'articles/{}'.format(corpus)
    corpus = corpus.replace('-', ' ')
    for filename in (i for i in filter(lambda f: f.split('.')[-1] == 'txt', listdir(folder))):
        File_Name.append(filename)
        filename = '{}/{}'.format(folder, filename)
        try: content = open(filename, 'r', encoding='utf-8').read()
        except UnicodeDecodeError: content = open(filename, 'r').read()
        Content.append(content)
        Category.append(corpus)
        Complete_Filename.append(filename)
        id.append(category_map[corpus])
        News_length.append(len(content))
        
df = pd.DataFrame()
df['File_Name'] = File_Name
df['Content'] = Content
df['Category'] = Category
df['Complete_Filename'] = Complete_Filename
df['id'] = id
df['News_length'] = News_length

if not exists('Pickles'): mkdir('Pickles')
with open('Pickles/initial_dataset.pickle', 'wb') as file: file.write(pickle.dumps(df))
    
df.head()
# Out:
#                                            File_Name  \
# 0  2017-07_302049_bekas-isteri-adi-putra-didakwa-...
# 1  2017-07_303332_sebutan-kes-19-penuntut-upnm-14...
# 2  2017-07_307248_mat-motor-terkepung-391-saman-d...
# 3  2017-08_310014_guna-vsp-bantu-cegah-jenayah-po...
# 4  2017-08_318783_lelaki-nigeria-tak-dapat-rogol-...
#
#                                              Content    Category  \
# 0  SEREMBAN: Bekas isteri kedua pelakon Adi Putra...  berita kes
# 1  KUALA LUMPUR: Mahkamah Majistret menetapkan 14...  berita kes
# 2  KUALA LUMPUR: Sebanyak 391 saman dikeluarkan a...  berita kes
# 3  KUANTAN: Polis Diraja Malaysia (PDRM) mahu leb...  berita kes
# 4  SUBANG JAYA: Kehadiran kereta peronda polis (M...  berita kes
#
#                                    Complete_Filename  id  News_length
# 0  articles/berita-kes/2017-07_302049_bekas-ister...   0         1069
# 1  articles/berita-kes/2017-07_303332_sebutan-kes...   0         2171
# 2  articles/berita-kes/2017-07_307248_mat-motor-t...   0         2080
# 3  articles/berita-kes/2017-08_310014_guna-vsp-ba...   0         1844
# 4  articles/berita-kes/2017-08_318783_lelaki-nige...   0         1373

# %%
# Special character cleaning
df['Content_Parsed'] = df['Content'].str.replace("\r", " ")
df['Content_Parsed'] = df['Content_Parsed'].str.replace("\n", " ")
df['Content_Parsed'] = df['Content_Parsed'].str.replace("    ", " ")

# Double quotes removal
df['Content_Parsed'] = df['Content_Parsed'].str.replace('"', '')

# %%
# Lowercasing all letters
df['Content_Parsed'] = df['Content_Parsed'].str.lower()

# %%
# Removing punctuation signs
punctuation_signs = list("?:!.,;")
df['Content_Parsed'] = df['Content_Parsed']

for punct_sign in punctuation_signs:
    df['Content_Parsed'] = df['Content_Parsed'].str.replace(punct_sign, '')

# %%
# Stemming/Lemmatization process
df['Content_Parsed'] = df['Content_Parsed'].apply(lambda x: stemmer.stem(x))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-8605f57054ab> in <module>
#       1 # Stemming/Lemmatization process
# ----> 2 df['Content_Parsed'] = df['Content_Parsed'].apply(lambda x: stemmer.stem(x))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-7-8605f57054ab> in <lambda>(x)
#       1 # Stemming/Lemmatization process
# ----> 2 df['Content_Parsed'] = df['Content_Parsed'].apply(lambda x: stemmer.stem(x))
#
# C:\ProgramData\Anaconda3\lib\site-packages\Sastrawi\Stemmer\CachedStemmer.py in stem(self, text)
#      18                 stems.append(self.cache.get(word))
#      19             else:
# ---> 20                 stem = self.delegatedStemmer.stem(word)
#      21                 self.cache.set(word, stem)
#      22                 stems.append(stem)
#
# C:\ProgramData\Anaconda3\lib\site-packages\Sastrawi\Stemmer\Stemmer.py in stem(self, text)
#      25
#      26         for word in words:
# ---> 27             stems.append(self.stem_word(word))
#      28
#      29         return ' '.join(stems)
#
# C:\ProgramData\Anaconda3\lib\site-packages\Sastrawi\Stemmer\Stemmer.py in stem_word(self, word)
#      34             return self.stem_plural_word(word)
#      35         else:
# ---> 36             return self.stem_singular_word(word)
#      37
#      38     def is_plural(self, word):
#
# C:\ProgramData\Anaconda3\lib\site-packages\Sastrawi\Stemmer\Stemmer.py in stem_singular_word(self, word)
#      82         """Stem a singular word to its common stem form."""
#      83         context = Context(word, self.dictionary, self.visitor_provider)
# ---> 84         context.execute()
#      85
#      86         return context.result
#
# C:\ProgramData\Anaconda3\lib\site-packages\Sastrawi\Stemmer\Context\Context.py in execute(self)
#      35
#      36         #step 1 - 5
# ---> 37         self.start_stemming_process()
#      38
#      39         #step 6
#
# C:\ProgramData\Anaconda3\lib\site-packages\Sastrawi\Stemmer\Context\Context.py in start_stemming_process(self)
#      78
#      79         #step 4, 5
# ---> 80         self.remove_prefixes()
#      81         if self.dictionary.contains(self.current_word):
#      82             return
#
# C:\ProgramData\Anaconda3\lib\site-packages\Sastrawi\Stemmer\Context\Context.py in remove_prefixes(self)
#      87     def remove_prefixes(self):
#      88         for i in range(3):
# ---> 89             self.accept_prefix_visitors(self.prefix_pisitors)
#      90             if self.dictionary.contains(self.current_word):
#      91                 return
#
# C:\ProgramData\Anaconda3\lib\site-packages\Sastrawi\Stemmer\Context\Context.py in accept_prefix_visitors(self, visitors)
#     109         for visitor in visitors:
#     110             self.accept(visitor)
# --> 111             if self.dictionary.contains(self.current_word):
#     112                 return self.current_word
#     113             if self.process_is_stopped:
#
# KeyboardInterrupt:

# %%
# Removing stop words
for stop_word in stop_words:
    df['Content_Parsed'] = df['Content_Parsed'].str.replace(r'\b{}\b'.format(stop_word), '')

# Replacing consequtive whitespaces more than 1 with a single space
df['Content_Parsed'] = df['Content_Parsed'].apply(lambda x: re.sub(r'\s\s+', ' ', x))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-53613f2ade76> in <module>
#       1 # Removing stop words
#       2 for stop_word in stop_words:
# ----> 3     df['Content_Parsed'] = df['Content_Parsed'].str.replace(r'\b{}\b'.format(stop_word), '')
#       4
#       5 # Replacing consequtive whitespaces more than 1 with a single space
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py in wrapper(self, *args, **kwargs)
#    1841                 )
#    1842                 raise TypeError(msg)
# -> 1843             return func(self, *args, **kwargs)
#    1844
#    1845         wrapper.__name__ = func_name
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py in replace(self, pat, repl, n, case, flags, regex)
#    2714     def replace(self, pat, repl, n=-1, case=None, flags=0, regex=True):
#    2715         result = str_replace(
# -> 2716             self._parent, pat, repl, n=n, case=case, flags=flags, regex=regex
#    2717         )
#    2718         return self._wrap_result(result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py in str_replace(arr, pat, repl, n, case, flags, regex)
#     630         f = lambda x: x.replace(pat, repl, n)
#     631
# --> 632     return _na_map(f, arr)
#     633
#     634
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py in _na_map(f, arr, na_result, dtype)
#     103 def _na_map(f, arr, na_result=np.nan, dtype=object):
#     104     # should really _check_ for NA
# --> 105     return _map(f, arr, na_mask=True, na_value=na_result, dtype=dtype)
#     106
#     107
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py in _map(f, arr, na_mask, na_value, dtype)
#     118         try:
#     119             convert = not all(mask)
# --> 120             result = lib.map_infer_mask(arr, f, mask.view(np.uint8), convert)
#     121         except (TypeError, AttributeError) as e:
#     122             # Reraise the exception if callable `f` got wrong number of args.
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer_mask()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py in <lambda>(x)
#     618             n = n if n >= 0 else 0
#     619             compiled = re.compile(pat, flags=flags)
# --> 620             f = lambda x: compiled.sub(repl=repl, string=x, count=n)
#     621         else:
#     622             f = lambda x: x.replace(pat, repl, n)
#
# KeyboardInterrupt:

# %%
df.head()
# Out:
#                                            File_Name    Category  \
# 0  2017-07_302049_bekas-isteri-adi-putra-didakwa-...  berita kes
# 1  2017-07_303332_sebutan-kes-19-penuntut-upnm-14...  berita kes
# 2  2017-07_307248_mat-motor-terkepung-391-saman-d...  berita kes
# 3  2017-08_310014_guna-vsp-bantu-cegah-jenayah-po...  berita kes
# 4  2017-08_318783_lelaki-nigeria-tak-dapat-rogol-...  berita kes
#
#                                    Complete_Filename  \
# 0  articles/berita-kes/2017-07_302049_bekas-ister...
# 1  articles/berita-kes/2017-07_303332_sebutan-kes...
# 2  articles/berita-kes/2017-07_307248_mat-motor-t...
# 3  articles/berita-kes/2017-08_310014_guna-vsp-ba...
# 4  articles/berita-kes/2017-08_318783_lelaki-nige...
#
#                                              Content  Category_Code  \
# 0  SEREMBAN: Bekas isteri kedua pelakon Adi Putra...              0
# 1  KUALA LUMPUR: Mahkamah Majistret menetapkan 14...              0
# 2  KUALA LUMPUR: Sebanyak 391 saman dikeluarkan a...              0
# 3  KUANTAN: Polis Diraja Malaysia (PDRM) mahu leb...              0
# 4  SUBANG JAYA: Kehadiran kereta peronda polis (M...              0
#
#                                       Content_Parsed
# 0  seremban bekas isteri kedua pelakon adi putra ...
# 1  kuala lumpur mahkamah majistret menetapkan 14 ...
# 2  kuala lumpur sebanyak 391 saman dikeluarkan at...
# 3  kuantan polis diraja malaysia (pdrm) mahu lebi...
# 4  subang jaya kehadiran kereta peronda polis (mp...

# %%
list_columns = ["File_Name", "Category", "Complete_Filename", "Content", "id", "Content_Parsed"]
df = df[list_columns]

df = df.rename(columns={'id': 'Category_Code'})

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(df['Content_Parsed'], 
                                                    df['Category_Code'], 
                                                    test_size=0.15, 
                                                    random_state=8)
X_train, y_train
# Out:
# (7455    tahniah diucapkan kepada kerajaan kerana berja...
#  7071    kuala lumpur “tidak semestinya kerap muncul di...
#  6388    makkah lebih dua juta umat islam memulakan iba...
#  5508    kuala lumpur bursa malaysia ditutup paras para...
#  121     kuala lumpur mahkamah tinggi menetapkan pada r...
#                                ...
#  6995    kuala lumpur penyanyi datuk nassier wahab bers...
#  2181    kuala lumpur sultan perak sultan nazrin muizzu...
#  2033    kuala lumpur muara sungai yang cetek akibat lu...
#  9556    sepang “saya tidak kisah digelar ‘mr 3 meters’...
#  4547    kuala lumpur memiliki rumah impian pastinya me...
#  Name: Content_Parsed, Length: 8137, dtype: object, 7455    30
#  7071    20
#  6388    15
#  5508     9
#  121      0
#          ..
#  6995    20
#  2181     1
#  2033     1
#  9556    40
#  4547     6
#  Name: Category_Code, Length: 8137, dtype: int64)

# %%
# Parameter election
ngram_range = (1,2)
min_df = 10
max_df = 1.
max_features = 300

# %%
tfidf = TfidfVectorizer(encoding='utf-8',
                        ngram_range=ngram_range,
                        stop_words=None,
                        lowercase=False,
                        max_df=max_df,
                        min_df=min_df,
                        max_features=max_features,
                        norm='l2',
                        sublinear_tf=True)
                        
features_train = tfidf.fit_transform(X_train).toarray()
labels_train = y_train
print(features_train.shape)

print(len(X_test.index))
features_test = tfidf.transform(X_test).toarray()
labels_test = y_test
print(features_test.shape)
# Out:
# (8137, 300)
# 1436
# (1436, 300)

# %%
from sklearn.feature_selection import chi2
import numpy as np

for Product, category_id in sorted(category_map.items()):
    features_chi2 = chi2(features_train, labels_train == category_id)
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
    bigrams = [v for v in feature_names if len(v.split(' ')) == 2]
    print("# '{}' category:".format(Product))
    print("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-5:])))
    print("  . Most correlated bigrams:\n. {}".format('\n. '.join(bigrams[-2:])))
    print("")

# %%
# X_train
with open('Pickles/X_train.pickle', 'wb') as output:
    pickle.dump(X_train, output)
    
# X_test    
with open('Pickles/X_test.pickle', 'wb') as output:
    pickle.dump(X_test, output)
    
# y_train
with open('Pickles/y_train.pickle', 'wb') as output:
    pickle.dump(y_train, output)
    
# y_test
with open('Pickles/y_test.pickle', 'wb') as output:
    pickle.dump(y_test, output)
    
# df
with open('Pickles/df.pickle', 'wb') as output:
    pickle.dump(df, output)
    
# features_train
with open('Pickles/features_train.pickle', 'wb') as output:
    pickle.dump(features_train, output)

# labels_train
with open('Pickles/labels_train.pickle', 'wb') as output:
    pickle.dump(labels_train, output)

# features_test
with open('Pickles/features_test.pickle', 'wb') as output:
    pickle.dump(features_test, output)

# labels_test
with open('Pickles/labels_test.pickle', 'wb') as output:
    pickle.dump(labels_test, output)
    
# TF-IDF object
with open('Pickles/tfidf.pickle', 'wb') as output:
    pickle.dump(tfidf, output)
